# %%
seq_file = r'./datasets/searches\DIAUmpire\DIAUmpire_RA957_seqs.tsv'
save_as = './model/RA957_HLA_no_pretrain_model.pth'
pretrained_model = None

# %%
import pandas as pd
pep_df = pd.read_csv(seq_file)
pep_df['nAA'] = pep_df.sequence.str.len()
pep_df['HLA'] = 1
pep_df
# Out:
#           sequence  nAA  HLA
# 0       ETQGQQPPQR   10    1
# 1      ESAPEGQAQQR   11    1
# 2        NRNDQEATL    9    1
# 3        EHVKEVQQL    9    1
# 4        NHHLQETSF    9    1
# ...            ...  ...  ...
# 16747    EHMELVSRL    9    1
# 16748   VTPQIDSSRI   10    1
# 16749   MPVSELTDKL   10    1
# 16750   IPISHIDDVL   10    1
# 16751    DAVRTEETK    9    1
#
# [15987 rows x 3 columns]

# %%
def split_to_two_dfs(df, ratio=0.8):
    train_df = df.sample(frac=ratio, replace=False)
    test_df = df.drop(train_df.index)
    return train_df.reset_index(drop=True), test_df.reset_index(drop=True)

pos_train_df, pos_test_df = split_to_two_dfs(pep_df, 0.8)

# %%
from peptdeep_hla.utils import get_random_sequences

def concat_neg_df(pos_df, prot_df):
    df_list = [pos_df]
    for nAA, group_df in pos_df.groupby('nAA'):
        rnd_seqs = get_random_sequences(
            prot_df, 
            n=len(group_df),
            pep_len = nAA
        )
        df_list.append(pd.DataFrame(
            dict(sequence=rnd_seqs,nAA=nAA,HLA=0)
        ))
    return pd.concat(df_list).reset_index(drop=True)
# Out:
#             sequence  nAA  HLA
# 0        RVIEEAKTAFL   11    1
# 1     TDAWGIKVERVEIK   14    1
# 2        IPNPQERTLTL   11    1
# 3       DTAGTEQFTAMR   12    1
# 4          YYDPMISKL    9    1
# ...              ...  ...  ...
# 3161  AEAVSHIQSSGPRR   14    0
# 3162  APLYKVRFPKVQLQ   14    0
# 3163  RRVLLTQAKNQFAA   14    0
# 3164  IEYKDFKLIYRQYA   14    0
# 3165  KEAKEFAKKVQELQ   14    0
#
# [3166 rows x 3 columns]

# %%
def evaluate(model, test_df, prob=0.5):
    model.predict(test_df)
    test_df[test_df.HLA_prob_pred>prob]['HLA'].mean(), test_df[test_df.HLA_prob_pred>prob]['HLA'].sum()/len(test_df)*2

# %% [markdown]
# ## PyTorch Classifier

# %%
from peptdeep_hla.HLA_class_I import HLA_Class_I_Classifier

# %% [markdown]
# ## Build, train and predict

# %%
model = HLA_Class_I_Classifier(
    fasta_files=['/User/Feng/fasta/uniprot_human_reviewed_20210309.fasta']
)
if pretrained_model:
    model.load(pretrained_model)
model.get_parameter_num()
# Out:
# 1669697

# %%
model.train(pos_train_df, epoch=100, warmup_epoch=20, verbose=True)
# Out:
# [Training] Epoch=1, lr=5e-06, loss=0.6939418395360311
# [Training] Epoch=2, lr=1e-05, loss=0.6938882946968079
# [Training] Epoch=3, lr=1.5e-05, loss=0.6937669595082601
# [Training] Epoch=4, lr=2e-05, loss=0.6935871243476868
# [Training] Epoch=5, lr=2.5e-05, loss=0.6933180014292399
# [Training] Epoch=6, lr=3e-05, loss=0.6928277373313904
# [Training] Epoch=7, lr=3.5e-05, loss=0.6917666554450989
# [Training] Epoch=8, lr=4e-05, loss=0.6881247838338216
# [Training] Epoch=9, lr=4.5e-05, loss=0.6750718553860983
# [Training] Epoch=10, lr=5e-05, loss=0.6374742309252421
# [Training] Epoch=11, lr=5.500000000000001e-05, loss=0.5830994645754496
# [Training] Epoch=12, lr=6e-05, loss=0.49845558603604634
# [Training] Epoch=13, lr=6.500000000000001e-05, loss=0.45616323749224347
# [Training] Epoch=14, lr=7e-05, loss=0.4299861987431844
# [Training] Epoch=15, lr=7.500000000000001e-05, loss=0.40282535354296367
# [Training] Epoch=16, lr=8e-05, loss=0.3884335776170095
# [Training] Epoch=17, lr=8.5e-05, loss=0.37744767864545187
# [Training] Epoch=18, lr=9e-05, loss=0.36237700581550597
# [Training] Epoch=19, lr=9.5e-05, loss=0.3563406844933828
# [Training] Epoch=20, lr=0.0001, loss=0.3414446492989858
# [Training] Epoch=21, lr=9.996145181203615e-05, loss=0.32167023022969565
# [Training] Epoch=22, lr=9.98458666866564e-05, loss=0.3073413719733556
# [Training] Epoch=23, lr=9.965342284774632e-05, loss=0.2954588284095128
# [Training] Epoch=24, lr=9.938441702975689e-05, loss=0.29898883899052936
# [Training] Epoch=25, lr=9.903926402016153e-05, loss=0.29139388700326285
# [Training] Epoch=26, lr=9.861849601988383e-05, loss=0.2886980126301448
# [Training] Epoch=27, lr=9.812276182268236e-05, loss=0.27450943887233736
# [Training] Epoch=28, lr=9.755282581475769e-05, loss=0.27277610301971433
# [Training] Epoch=29, lr=9.690956679612421e-05, loss=0.26933393279711404
# [Training] Epoch=30, lr=9.619397662556435e-05, loss=0.2717393477757772
# [Training] Epoch=31, lr=9.540715869125407e-05, loss=0.25879761079947156
# [Training] Epoch=32, lr=9.45503262094184e-05, loss=0.2673611998558044
# [Training] Epoch=33, lr=9.362480035363986e-05, loss=0.2694700300693512
# [Training] Epoch=34, lr=9.263200821770461e-05, loss=0.2510036647319794
# [Training] Epoch=35, lr=9.157348061512727e-05, loss=0.2662539025147756
# [Training] Epoch=36, lr=9.045084971874738e-05, loss=0.24280032714207966
# [Training] Epoch=37, lr=8.926584654403724e-05, loss=0.2595801909764608
# [Training] Epoch=38, lr=8.802029828000156e-05, loss=0.2479500353336334
# [Training] Epoch=39, lr=8.671612547178428e-05, loss=0.24815136392911274
# [Training] Epoch=40, lr=8.535533905932738e-05, loss=0.2510997066895167
# [Training] Epoch=41, lr=8.39400372766471e-05, loss=0.24639734824498494
# [Training] Epoch=42, lr=8.247240241650918e-05, loss=0.24257112443447112
# [Training] Epoch=43, lr=8.095469746549172e-05, loss=0.249191885193189
# [Training] Epoch=44, lr=7.938926261462366e-05, loss=0.23673765261967977
# [Training] Epoch=45, lr=7.777851165098012e-05, loss=0.2359275132417679
# [Training] Epoch=46, lr=7.612492823579745e-05, loss=0.23716100553671518
# [Training] Epoch=47, lr=7.443106207484776e-05, loss=0.23165257970492045
# [Training] Epoch=48, lr=7.269952498697734e-05, loss=0.23869035144646963
# [Training] Epoch=49, lr=7.09329868768714e-05, loss=0.2517813205718994
# [Training] Epoch=50, lr=6.91341716182545e-05, loss=0.22872155805428823
# [Training] Epoch=51, lr=6.730585285387465e-05, loss=0.25044658680756887
# [Training] Epoch=52, lr=6.545084971874738e-05, loss=0.23228965202967325
# [Training] Epoch=53, lr=6.357202249325371e-05, loss=0.2298621987303098
# [Training] Epoch=54, lr=6.167226819279528e-05, loss=0.22518091301123302
# [Training] Epoch=55, lr=5.9754516100806423e-05, loss=0.22224685847759246
# [Training] Epoch=56, lr=5.782172325201155e-05, loss=0.217966424425443
# [Training] Epoch=57, lr=5.587686987289189e-05, loss=0.2141704648733139
# [Training] Epoch=58, lr=5.392295478639225e-05, loss=0.21810689071814218
# [Training] Epoch=59, lr=5.196299078795344e-05, loss=0.21884277562300364
# [Training] Epoch=60, lr=5e-05, loss=0.21658315062522887
# [Training] Epoch=61, lr=4.8037009212046586e-05, loss=0.21544898450374603
# [Training] Epoch=62, lr=4.607704521360776e-05, loss=0.21259844700495403
# [Training] Epoch=63, lr=4.412313012710813e-05, loss=0.21040500303109486
# [Training] Epoch=64, lr=4.2178276747988446e-05, loss=0.21651918093363445
# [Training] Epoch=65, lr=4.0245483899193595e-05, loss=0.20980956256389618
# [Training] Epoch=66, lr=3.832773180720475e-05, loss=0.2150951663653056
# [Training] Epoch=67, lr=3.642797750674629e-05, loss=0.2110369920730591
# [Training] Epoch=68, lr=3.4549150281252636e-05, loss=0.20966594517230988
# [Training] Epoch=69, lr=3.2694147146125345e-05, loss=0.2097440759340922
# [Training] Epoch=70, lr=3.086582838174551e-05, loss=0.20913769900798798
# [Training] Epoch=71, lr=2.9067013123128613e-05, loss=0.214725931485494
# [Training] Epoch=72, lr=2.7300475013022663e-05, loss=0.21072320838769276
# [Training] Epoch=73, lr=2.556893792515227e-05, loss=0.20447865625222525
# [Training] Epoch=74, lr=2.3875071764202563e-05, loss=0.20366322894891103
# [Training] Epoch=75, lr=2.2221488349019903e-05, loss=0.20225018858909607
# [Training] Epoch=76, lr=2.061073738537635e-05, loss=0.20822754204273225
# [Training] Epoch=77, lr=1.9045302534508297e-05, loss=0.20523635745048524
# [Training] Epoch=78, lr=1.7527597583490822e-05, loss=0.20665185650189719
# [Training] Epoch=79, lr=1.6059962723352904e-05, loss=0.20209520161151887
# [Training] Epoch=80, lr=1.4644660940672627e-05, loss=0.2048355167110761
# [Training] Epoch=81, lr=1.3283874528215733e-05, loss=0.1968097006281217
# [Training] Epoch=82, lr=1.1979701719998453e-05, loss=0.19490566849708557
# [Training] Epoch=83, lr=1.0734153455962765e-05, loss=0.20545412302017213
# [Training] Epoch=84, lr=9.549150281252633e-06, loss=0.20250455637772877
# [Training] Epoch=85, lr=8.426519384872733e-06, loss=0.20110132296880087
# [Training] Epoch=86, lr=7.367991782295391e-06, loss=0.20462739566961924
# [Training] Epoch=87, lr=6.375199646360142e-06, loss=0.19681485990683237
# [Training] Epoch=88, lr=5.449673790581611e-06, loss=0.20291281441847484
# [Training] Epoch=89, lr=4.592841308745932e-06, loss=0.19859758913516998
# [Training] Epoch=90, lr=3.8060233744356633e-06, loss=0.20468570987383525
# [Training] Epoch=91, lr=3.0904332038757977e-06, loss=0.1981384446223577
# [Training] Epoch=92, lr=2.4471741852423237e-06, loss=0.20617630978425344
# [Training] Epoch=93, lr=1.8772381773176417e-06, loss=0.2085905432701111
# [Training] Epoch=94, lr=1.3815039801161721e-06, loss=0.195387934645017
# [Training] Epoch=95, lr=9.607359798384785e-07, loss=0.2041465938091278
# [Training] Epoch=96, lr=6.15582970243117e-07, loss=0.19470429221789043
# [Training] Epoch=97, lr=3.465771522536854e-07, loss=0.20434390604496003
# [Training] Epoch=98, lr=1.5413331334360182e-07, loss=0.19731500546137493
# [Training] Epoch=99, lr=3.8548187963854956e-08, loss=0.19458578924338024
# [Training] Epoch=100, lr=0.0, loss=0.1926902562379837

# %%
model.save(save_as)

# %%
test_df = concat_neg_df(pos_test_df, model.protein_df)
model.predict(test_df)
# Out:
#             sequence  nAA  HLA  HLA_prob_pred
# 0        ETILASSGTDR   11    1       0.988257
# 1          RLAQHITYV    9    1       0.963363
# 2          DTITETDLR    9    1       0.984478
# 3          HHVLQNDVL    9    1       0.985039
# 4          KLDQDLNEV    9    1       0.936592
# ...              ...  ...  ...            ...
# 6421  KLRRNGLEPVTYHR   14    0       0.025646
# 6422  AFDGDGDRNMILGK   14    0       0.420663
# 6423  QIWFQNRRSRLLLQ   14    0       0.004337
# 6424  FSLMGDCARWELSE   14    0       0.003082
# 6425  HITIDIRNVCVFLA   14    0       0.004777
#
# [6426 rows x 4 columns]

# %%
prob=0.7
print("Precision =", test_df[test_df.HLA_prob_pred>prob]['HLA'].mean())
print("Recall =", test_df[test_df.HLA_prob_pred>prob]['HLA'].sum()/len(test_df)*2)
print("False Positive Rate =", 1-(1-test_df[test_df.HLA_prob_pred<prob]['HLA']).sum()/len(test_df)*2)
# Out:
# Precision = 0.9396175779939617
# Recall = 0.87177093059446
# False Positive Rate = 0.05602240896358546

# %% [markdown]
# # Apply the model for all protein sequences
#
# The biggest computational problem is that non-specific digestion and removing redundunt peptide sequences. Here we used longest common prefix (LCP)-based algorithm in `alphapeptdeep` (Feng) to fast generate all non-redundunt substrings. Digestion for 20K proteins could be done in seconds using LCP algorithm.

# %% [markdown]
# # Get all sequences with >prob (0.7) predicted probabilities

# %%
hla_df = model.predict_from_proteins(prob_threshold=prob)
hla_df
# Out:
#           start_pos  end_pos  nAA  HLA_prob_pred        sequence
# 5           4736571  4736579    8       0.756716        QAFHSVAF
# 29          4736595  4736603    8       0.815665        RLKDLLGR
# 99          4736651  4736659    8       0.817420        FSSRAVAR
# 131         4736620  4736628    8       0.817954        GPEPGQAR
# 144         4736436  4736444    8       0.832021        TTYTHCRL
# ...             ...      ...  ...            ...             ...
# 73180109    2044507  2044521   14       0.740652  MHQQQELQREGQRL
# 73180133    6918665  6918679   14       0.955907  SVVPESDTSERSSM
# 73180150     626345   626359   14       0.962231  EPSNEPSPALFHKK
# 73180161    2044502  2044516   14       0.725886  ELDASMHQQQELQR
# 73180188     490674   490688   14       0.969660  GLGGEGGGTGPLSM
#
# [3677391 rows x 5 columns]

# %%
hla_df.to_csv('Predicted_RA957_no_pretrain_HLA.tsv',index=False, sep="\t")
